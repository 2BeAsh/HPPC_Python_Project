# %%
#%load_ext line_profiler

from contextlib import redirect_stdout
import runpy

# %prun runpy.run_module(mod_name='task_farm_HEP_seq', run_name='__main__')
# Out:
#          94686 function calls (94649 primitive calls) in 3.238 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      6561    1.885    0.000    2.813    0.000 overall.py:42(task_function)
#     13128    0.890    0.000    0.890    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.312    0.312    0.316    0.316 c_parser_wrapper.py:222(read)
#         5    0.061    0.012    0.061    0.012 {built-in method posix.stat}
#     13124    0.018    0.000    0.912    0.000 fromnumeric.py:71(_wrapreduction)
#         1    0.009    0.009    0.348    0.348 overall.py:5(__init__)
#         1    0.008    0.008    2.822    2.822 task_farm_HEP_seq.py:11(master)
#      6562    0.007    0.000    0.495    0.000 fromnumeric.py:2177(sum)
#      6561    0.006    0.000    0.431    0.000 fromnumeric.py:2421(all)
#     13124    0.005    0.000    0.005    0.000 fromnumeric.py:72(<dictcomp>)
# ...

# %%
# %prun runpy.run_module(mod_name='task_farm_HEP_seq - initial working code', run_name='__main__')
# Out:
# i am rank 0
# I am the master! I have 0 workers
# Nsig = 66346, Nbkg = 183525, Ntot = 249871
# Best accuracy optained: 0.736576
# Final cuts:
# averageInteractionsPerCrossing: 41.376566
# p_Rhad: 0.059930
# p_Rhad1: 0.037787
# p_TRTTrackOccupancy: 0.468433
# p_topoetcone40: 4.960266
# p_eTileGap3Cluster: 0.391874
# p_phiModCalo: 0.000015
# p_etaModCalo: 0.012526
# Number of settings: 6561
# Elapsed time: 14.89 seconds
#          92576 function calls (92575 primitive calls) in 15.628 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      6561   14.321    0.002   14.887    0.002 task_farm_HEP_seq - initial working code.py:42(task_function)
#         3    0.581    0.194    0.589    0.196 {built-in method numpy.core._multiarray_umath._load_from_filelike}
#      6565    0.492    0.000    0.492    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.071    0.071    0.071    0.071 {built-in method posix.open}
# ...

# %%
filename = 'mc_ggH_16_13TeV_Zee_EGAM1_calocells_16249871.csv'
import pandas as pd
file =  pd.read_csv(filename,skiprows=1)
test = file.to_numpy()
test[0:5,0:5]
import numpy as np
t = np.linspace(0,5,10)
print(t.shape)
print(t[1].shape==())
# Out:
# (10,)
# True
